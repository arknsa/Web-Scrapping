# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.webometrics.info/en/Asia/Indonesia%20'
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html dir="ltr" version="XHTML+RDFa 1.0" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
# <head profile="http://www.w3.org/1999/xhtml/vocab"><!--start head section-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <link href="https://www.webometrics.info/sites/default/files/cibermetria%2520cubierta%2520completa_4.jpg" rel="shortcut icon" type="image/jpeg"/>
# ...

# %%
soup.find('table')
# Out:
# <table class="sticky-enabled">
# ...

# %%
soup.find_all('table')[0]
# Out:
# <table class="sticky-enabled">
# ...

# %%
soup.find('table', class_ = 'sticky-enabled')
# Out:
# <table class="sticky-enabled">
# ...

# %%
table = soup.find_all('table')[0]
table
# Out:
# <table class="sticky-enabled">
# ...

# %%
univ_rank = table.find_all('th')
univ_rank
# Out:
# [<th>ranking</th>,
#  <th class="active"><a class="active" href="/en/Asia/Indonesia%20?sort=desc&amp;order=World%20Rank" title="sort by World Rank">World Rank<img alt="sort descending" height="13" src="https://www.webometrics.info/misc/arrow-desc.png" title="sort descending" typeof="foaf:Image" width="13"/></a></th>,
#  <th><a class="active" href="/en/Asia/Indonesia%20?sort=asc&amp;order=University" title="sort by University">University</a></th>,
#  <th><a class="active" href="/en/Asia/Indonesia%20?sort=asc&amp;order=Det." title="sort by Det.">Det.</a></th>,
#  <th><a class="active" href="/en/Asia/Indonesia%20?sort=asc&amp;order=Impact%20Rank%2A" title="sort by Impact Rank*">Impact Rank*</a></th>,
#  <th><a class="active" href="/en/Asia/Indonesia%20?sort=asc&amp;order=Openness%20Rank%2A" title="sort by Openness Rank*">Openness Rank*</a></th>,
# ...

# %%
univ_rank_titles = [title.text.strip() for title in univ_rank]

print(univ_rank_titles)
# Out:
# ['ranking', 'World Rank', 'University', 'Det.', 'Impact Rank*', 'Openness Rank*', 'Excellence Rank*']

# %%
df = pd.DataFrame(columns = univ_rank_titles)

df
# Out:
# Empty DataFrame
# Columns: [ranking, World Rank, University, Det., Impact Rank*, Openness Rank*, Excellence Rank*]
# Index: []

# %%
column_data = table.find_all('tr')
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data
    
df
# Out:
#    ranking World Rank                                         University Det.  \
# 0        1        561                              Universitas Indonesia
# 1        2        694                            Universitas Gadjah Mada
# 2        3        786  Institut Teknologi Bandung / Bandung Institute...
# 3        4        797                              Universitas Brawijaya
# 4        5        865                              Universitas Airlangga
# ..     ...        ...                                                ...  ...
# 95      96       5569         Universitas Katolik Widya Mandala Surabaya
# 96      97       5569    Institut Sains dan Teknologi AKPRIND Yogyakarta
# 97      98       5569                         Universitas Sulawesi Barat
# 98      99       5574                  Universitas Maritim Raja Ali Haji
# 99     100       5581          Institut Agama Islam Negeri IAIN Parepare
#
#    Impact Rank* Openness Rank* Excellence Rank*
# ...
